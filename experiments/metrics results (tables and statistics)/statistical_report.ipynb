# %% [markdown]
# # Results of the Friedman test and Nemenyi Post-hoc test

# %% [markdown]
# ### BASELINE: POPULATION

# %%
# %run generate_stat_report.py --pop
# Out:
# >> METRIC: #sg
# Statistical test: friedman
# p-value: 1.4435144950262733e-45
# Post-hoc test: nemenyi
# >> METRIC: length
# Statistical test: friedman
# p-value: 3.8092552691076015e-201
# Post-hoc test: nemenyi
# >> METRIC: sgCov
# Statistical test: friedman
# p-value: 1.9501456942881558e-187
# Post-hoc test: nemenyi
# >> METRIC: setCov
# Statistical test: friedman
# p-value: 2.7995301644912963e-245
# Post-hoc test: nemenyi
# >> METRIC: description redundancy
# Statistical test: friedman
# p-value: 2.6499954399265297e-260
# Post-hoc test: nemenyi
# >> METRIC: cover redundancy
# Statistical test: friedman
# p-value: 1.9113139598919208e-202
# Post-hoc test: nemenyi
# >> METRIC: CR
# Statistical test: friedman
# p-value: 6.86053804774097e-247
# Post-hoc test: nemenyi
# >> METRIC: model redundancy
# Statistical test: friedman
# p-value: 4.388142443469468e-264
# Post-hoc test: nemenyi

# %% [markdown]
# ### BASELINE: COMPLEMENT

# %%
# %run generate_stat_report.py --cpm
# Out:
# >> METRIC: #sg
# Statistical test: friedman
# p-value: 6.17962004805906e-64
# Post-hoc test: nemenyi
# >> METRIC: length
# Statistical test: friedman
# p-value: 1.0118015566151172e-206
# Post-hoc test: nemenyi
# >> METRIC: sgCov
# Statistical test: friedman
# p-value: 1.1949153172502136e-158
# Post-hoc test: nemenyi
# >> METRIC: setCov
# Statistical test: friedman
# p-value: 2.3258101719385103e-205
# Post-hoc test: nemenyi
# >> METRIC: description redundancy
# Statistical test: friedman
# p-value: 3.007936093181912e-224
# Post-hoc test: nemenyi
# >> METRIC: cover redundancy
# Statistical test: friedman
# p-value: 1.6042658902530003e-136
# Post-hoc test: nemenyi
# >> METRIC: CR
# Statistical test: friedman
# p-value: 1.8348324811166072e-162
# Post-hoc test: nemenyi
# >> METRIC: model redundancy
# Statistical test: friedman
# p-value: 6.592254523697533e-130
# Post-hoc test: nemenyi
